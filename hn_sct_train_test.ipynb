# %%
import pandas as pd
import numpy as np
import sklearn

import matplotlib
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
# %matplotlib inline

# %%
import torch

from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable

from trainer import fit,train_epoch
import numpy as np
cuda = torch.cuda.is_available()

# %%
from datasets import TripletSampling, BatchPairSampling
from networks import EmbeddingNet, TripletNet, SiameseNet
from losses import TripletLoss, HardHardNegativesBatchLoss, HardEasyNegativesBatchLoss, SCTLossCosine

# %%
def extract_embeddings(dataset, labels, model):
    with torch.no_grad():
        model.eval()
        embeddings = []

        for data in dataset:

            embeddings.append( 
                np.array( 
                    model.get_embedding(data).detach().numpy() ) )

    return np.array(embeddings), labels

def plot_embeddings(embeddings, targets, xlim=None, ylim=None):
    plt.figure(figsize=(10,10))
    targets = np.array(targets)
    colors = ['r', 'b']
    shapes = ['*', '^']
    for cls in set(targets):
        mask = targets == cls
        cls_emb = embeddings[mask]
        plt.scatter(cls_emb[:,0], cls_emb[:,1], alpha=0.5, marker = shapes[cls],c = colors[cls])

    plt.legend(set(targets))
    
def dissim_matrix(data, name):
    """helper for mds visualization"""
    from scipy.spatial import distance
    return distance.cdist(data, data, metric= name)

def smaples_for_plotting(percentage, labels, data):
    """ reduce # of data, for plotting"""
    percentage = 0.5
    labels = np.array(labels)
    label_to_indices = {label: np.where(labels == label)[0]
                             for label in labels}


    true_num = int( len(label_to_indices[1]) * percentage )
    false_num = int( len(label_to_indices[0]) * percentage )

    positive_index = np.random.choice( label_to_indices[1], true_num)
    negative_index= np.random.choice(label_to_indices[0], false_num)

    index = np.concatenate( [positive_index, negative_index], axis = 0)

    return data[index], labels[index]


tsne = TSNE(n_components=2, perplexity = 5, learning_rate='auto',init='random')
mds = sklearn.manifold.MDS(n_components=2,metric= True, 
                                  n_init=4, 
                                  max_iter=100,
                                  verbose=0, eps=0.001, n_jobs=-1, random_state= 10, dissimilarity='precomputed')

# %% [markdown]
# ## Friedman

# %%
friedman = pd.read_csv('./data/Friedman_data.csv')
drop_columns = ['y']
friedman = friedman.drop(drop_columns, axis = 1)

# %%
friedman_shuffled = friedman.sample(frac=1).reset_index(drop=True)
from sklearn.mixture import GaussianMixture

# use Gs to do clustering
labels = GaussianMixture(n_components=2, random_state=0).fit_predict(friedman_shuffled)

# %%
train_X_fried, test_X_fried,train_label_fried, test_label_fried = train_test_split(
    friedman_shuffled, labels, test_size=0.33, random_state=42)

train_X_fried_tensor = torch.tensor(train_X_fried.values )
test_X_fried_tensor = torch.tensor(test_X_fried.values )

# %%
distance = None
margin = 1

lam = 1
# method = 'sct'
method = 'hn' #shn now is the best
loss_fn = SCTLossCosine( method = method, lam = lam)

lr = 1e-5

hidden_size = 20
embedding_size = 5
input_size = train_X_fried_tensor.shape[1]

net = EmbeddingNet(input_size, hidden_size, embedding_size)
siamese_net = SiameseNet(  embedding_net = net )



model = siamese_net
model = model.float() 
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 80

datasampler = BatchPairSampling( dataset = train_X_fried_tensor , labels= train_label_fried)
batch_size = 100
train_loader = torch.utils.data.DataLoader(datasampler, batch_size=batch_size, shuffle=True)

interval = 20

# %%
# %%time
fit(train_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, interval)
# Out:
# Train: [0/670 (0%)]	Loss: 0.693651
# Epoch: 1/80. Train set: Average loss: 0.3964
# Train: [0/670 (0%)]	Loss: 0.693681
# Epoch: 2/80. Train set: Average loss: 0.3964
# Train: [0/670 (0%)]	Loss: 0.693656
# Epoch: 3/80. Train set: Average loss: 0.5946
# Train: [0/670 (0%)]	Loss: 0.693628
# Epoch: 4/80. Train set: Average loss: 0.4955
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 5/80. Train set: Average loss: 0.3964
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 6/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.693661
# Epoch: 7/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 8/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 9/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.693658
# Epoch: 10/80. Train set: Average loss: 0.3964
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 11/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 12/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.693634
# Epoch: 13/80. Train set: Average loss: 0.3964
# Train: [0/670 (0%)]	Loss: 0.693633
# Epoch: 14/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 15/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 16/80. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 17/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 18/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 19/80. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 20/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.693689
# Epoch: 21/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 22/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 23/80. Train set: Average loss: 0.3964
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 24/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 25/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 26/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 27/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.693648
# Epoch: 28/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 29/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 30/80. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.693649
# Epoch: 31/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 32/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 33/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 34/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.693688
# Epoch: 35/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.693660
# Epoch: 36/80. Train set: Average loss: 0.3964
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 37/80. Train set: Average loss: 0.3964
# Train: [0/670 (0%)]	Loss: 0.693657
# Epoch: 38/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.693660
# Epoch: 39/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.693661
# Epoch: 40/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 41/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 42/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.693681
# Epoch: 43/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 44/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 45/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 46/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 47/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 48/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.693678
# Epoch: 49/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 50/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.693690
# Epoch: 51/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.693754
# Epoch: 52/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.693658
# Epoch: 53/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 54/80. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 55/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 56/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 57/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.693697
# Epoch: 58/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 59/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 60/80. Train set: Average loss: 0.4955
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 61/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.693653
# Epoch: 62/80. Train set: Average loss: 0.3964
# Train: [0/670 (0%)]	Loss: 0.693678
# Epoch: 63/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 64/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 65/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 66/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.693651
# Epoch: 67/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 68/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.693656
# Epoch: 69/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.693638
# Epoch: 70/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 71/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.693765
# Epoch: 72/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.693663
# Epoch: 73/80. Train set: Average loss: 0.2973
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 74/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 75/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 76/80. Train set: Average loss: 0.0991
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 77/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.693660
# Epoch: 78/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 79/80. Train set: Average loss: 0.1982
# Train: [0/670 (0%)]	Loss: 0.000000
# Epoch: 80/80. Train set: Average loss: 0.2973
# CPU times: user 3.98 s, sys: 171 ms, total: 4.16 s
# Wall time: 4.06 s

# %% [markdown]
# #### Visualize train

# %%
train_embs,train_labels = extract_embeddings(train_X_fried_tensor , train_label_fried, model)

# %%
name = 'cosine'
train_dis = dissim_matrix(train_embs, name)

# %%
embedded_2_train = mds.fit_transform(train_dis)
plot_embeddings(embedded_2_train, train_labels)

# %%
name = 'cosine'
train_orig_dis = dissim_matrix(train_X_fried_tensor, name)

embedded_2_train_orig = mds.fit_transform(train_orig_dis)
plot_embeddings(embedded_2_train_orig, train_labels)

# %% [markdown]
# #### visualize test

# %%
test_embs,test_labels = extract_embeddings(test_X_fried_tensor , test_label_fried, model)

# %%
name = 'cosine'
test_dis = dissim_matrix(test_embs, name)

# %%
embedded_2_test = mds.fit_transform(test_dis)
plot_embeddings(embedded_2_test, test_labels)

# %%
name = 'cosine'
test_orig_dis = dissim_matrix(test_X_fried_tensor, name)

embedded_2_test_orig = mds.fit_transform(test_orig_dis)
plot_embeddings(embedded_2_test_orig, test_labels)

# %% [markdown]
# ## Diffusion - chemical grouping

# %%
diffusion = pd.read_csv('./data/Diffusion_data.csv')
diffusion_shuffled = diffusion.sample(frac=1).reset_index(drop=True)
labels = []
for name in diffusion_shuffled ['group']:
    if name == 'transition_metal':
        labels.append(1)
    else:
        labels.append(0)

drop_columns = ['E_regression', 'E_regression_shift', 'group',
               'Material compositions 2', 'Material compositions 1']
diffusion_shuffled  = diffusion_shuffled .drop(drop_columns, axis = 1)

# %%
train_X_diffu, test_X_diffu,train_label_diffu, test_label_diffu = train_test_split(
    diffusion_shuffled, labels, test_size=0.33, random_state=42)

train_X_diffu_tensor = torch.tensor(train_X_diffu.values )
test_X_diffu_tensor = torch.tensor(test_X_diffu.values )

# %%
distance = None
margin = 2

lam = 1
# method = 'sct'
method = 'hn' #shn now is the best
loss_fn = SCTLossCosine( method = method, lam = lam)
lr = 1e-3

hidden_size = 100
embedding_size = 20
input_size = train_X_diffu_tensor.shape[1]
net = EmbeddingNet(input_size, hidden_size, embedding_size)
siamese_net = SiameseNet(  embedding_net = net )



model = siamese_net
model = model.float() 
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 20

datasampler = BatchPairSampling( dataset = train_X_diffu_tensor, labels= train_label_diffu)
batch_size = 100
train_loader = torch.utils.data.DataLoader(datasampler, batch_size=batch_size, shuffle=True)

interval = 10

# %%
# %%time
fit(train_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, interval)
# Out:
# Train: [0/273 (0%)]	Loss: 0.695516
# Epoch: 1/20. Train set: Average loss: 0.6944
# Train: [0/273 (0%)]	Loss: 0.693737
# Epoch: 2/20. Train set: Average loss: 0.6938
# Train: [0/273 (0%)]	Loss: 0.694035
# Epoch: 3/20. Train set: Average loss: 0.6941
# Train: [0/273 (0%)]	Loss: 0.694322
# Epoch: 4/20. Train set: Average loss: 0.6940
# Train: [0/273 (0%)]	Loss: 0.693879
# Epoch: 5/20. Train set: Average loss: 0.6938
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 6/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 7/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 8/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 9/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 10/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 11/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 12/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 13/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 14/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 15/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 16/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 17/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 18/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 19/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Epoch: 20/20. Train set: Average loss: 0.0000
# CPU times: user 495 ms, sys: 72.7 ms, total: 568 ms
# Wall time: 540 ms

# %% [markdown]
# #### Visualize train

# %%
train_embs,train_labels = extract_embeddings(train_X_diffu_tensor , train_label_diffu, model)
name = 'cosine'
train_dis = dissim_matrix(train_embs, name)
embedded_2_train = mds.fit_transform(train_dis)
plot_embeddings(embedded_2_train, train_labels)

# %%
name = 'cosine'
train_orig_dis = dissim_matrix(train_X_diffu_tensor, name)

embedded_2_train_orig = mds.fit_transform(train_orig_dis)
plot_embeddings(embedded_2_train_orig, train_labels)

# %% [markdown]
# #### Visualize test

# %%
test_embs,test_labels = extract_embeddings(test_X_diffu_tensor , test_label_diffu, model)
name = 'cosine'
test_dis = dissim_matrix(test_embs, name)
embedded_2_test = mds.fit_transform(test_dis)
plot_embeddings(embedded_2_test, test_labels)

# %%
name = 'cosine'
test_orig_dis = dissim_matrix(test_X_diffu_tensor, name)

embedded_2_test_orig = mds.fit_transform(test_orig_dis)
plot_embeddings(embedded_2_test_orig, test_labels)

# %% [markdown]
# ### Supercond - chemical grouping

# %%
supercond = pd.read_excel('./data/Supercon_data_features_selected.xlsx')
supercond_shuffled = supercond.sample(frac=1).reset_index(drop=True)

labels = []
for name in supercond['group']:
    if name == 'cuprates':
        labels.append(1)
    else:
        labels.append(0)
supercond['group'] = labels


drop_columns = [
                 'name',
                 'group',
                 'Tc', 'ln(Tc)'
                 ]
supercond_shuffled  = supercond_shuffled .drop(drop_columns, axis = 1)

# %%
train_X_supercond, test_X_supercond,train_label_supercond, test_label_supercond = train_test_split(
    supercond_shuffled, labels, test_size=0.33, random_state=42)

train_X_supercond_tensor = torch.tensor(train_X_supercond.values )
test_X_supercond_tensor = torch.tensor(test_X_supercond.values )

# %%
distance = None
margin = 2

lam = 1
# method = 'sct'
method = 'hn' #shn now is the best
loss_fn = SCTLossCosine( method = method, lam = lam)
lr = 1e-4

hidden_size = 100
embedding_size = 20
input_size = train_X_supercond_tensor.shape[1]
net = EmbeddingNet(input_size, hidden_size, embedding_size)
siamese_net = SiameseNet(  embedding_net = net )



model = siamese_net
model = model.float() 
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 50

datasampler = BatchPairSampling( dataset = train_X_supercond_tensor, labels= train_label_supercond)
batch_size = 200
train_loader = torch.utils.data.DataLoader(datasampler, batch_size=batch_size, shuffle=True)

interval = 200

# %%
# %%time
fit(train_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, interval)
# Out:
# Train: [0/4188 (0%)]	Loss: 0.693997
# Epoch: 1/50. Train set: Average loss: 0.6940
# Train: [0/4188 (0%)]	Loss: 0.693737
# Epoch: 2/50. Train set: Average loss: 0.6937
# Train: [0/4188 (0%)]	Loss: 0.693755
# Epoch: 3/50. Train set: Average loss: 0.6938
# Train: [0/4188 (0%)]	Loss: 0.693692
# Epoch: 4/50. Train set: Average loss: 0.6937
# Train: [0/4188 (0%)]	Loss: 0.693702
# Epoch: 5/50. Train set: Average loss: 0.6938
# Train: [0/4188 (0%)]	Loss: 0.693630
# Epoch: 6/50. Train set: Average loss: 0.3633
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 7/50. Train set: Average loss: 0.0330
# Train: [0/4188 (0%)]	Loss: 0.693633
# Epoch: 8/50. Train set: Average loss: 0.0991
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 9/50. Train set: Average loss: 0.0991
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 10/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 11/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 12/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 13/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 14/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 15/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 16/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 17/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 18/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 19/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 20/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 21/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 22/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 23/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 24/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 25/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 26/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 27/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 28/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 29/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 30/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 31/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 32/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 33/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 34/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 35/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 36/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 37/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 38/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 39/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 40/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 41/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 42/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 43/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 44/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 45/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 46/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 47/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 48/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 49/50. Train set: Average loss: 0.0000
# Train: [0/4188 (0%)]	Loss: 0.000000
# Epoch: 50/50. Train set: Average loss: 0.0000
# CPU times: user 17.5 s, sys: 4.42 s, total: 21.9 s
# Wall time: 18.3 s

# %% [markdown]
# #### Visualize train

# %%
train_embs,train_labels = extract_embeddings(train_X_supercond_tensor , train_label_supercond, model)


# sample some of them for plotting
embs_resample_train, labels_resample_train = smaples_for_plotting(0.5, train_label_supercond, train_embs)

name = 'cosine'
train_dis = dissim_matrix(embs_resample_train, name)
embedded_2_train = mds.fit_transform(train_dis)
plot_embeddings(embedded_2_train, labels_resample_train)

# %%
orig_data_train, labels_resample_orig_train = smaples_for_plotting(0.5, train_label_supercond,train_X_supercond_tensor)

name = 'cosine'
train_orig_dis = dissim_matrix(orig_data_train, name)

embedded_2_train_orig = mds.fit_transform(train_orig_dis)
plot_embeddings(embedded_2_train_orig, labels_resample_orig_train)

# %% [markdown]
# #### visual test

# %%
test_embs,test_labels = extract_embeddings(test_X_supercond_tensor , test_label_supercond, model)


# sample some of them for plotting
embs_resample_test, labels_resample_test = smaples_for_plotting(0.5, test_label_supercond, test_embs)

name = 'cosine'
test_dis = dissim_matrix(embs_resample_test, name)
embedded_2_test = mds.fit_transform(test_dis)
plot_embeddings(embedded_2_test, labels_resample_test)

# %%
orig_data_test, labels_resample_orig_test = smaples_for_plotting(0.5, test_label_supercond,test_X_supercond_tensor)

name = 'cosine'
test_orig_dis = dissim_matrix(orig_data_test, name)

embedded_2_test_orig = mds.fit_transform(test_orig_dis)
plot_embeddings(embedded_2_test_orig , labels_resample_orig_test)

# %% [markdown]
# ### Diffusion - gs mixture

# %%
diffusion = pd.read_csv('./data/Diffusion_data.csv')
diffusion_shuffled = diffusion.sample(frac=1).reset_index(drop=True)
drop_columns = ['E_regression', 'E_regression_shift', 'group',
               'Material compositions 2', 'Material compositions 1']
diffusion_shuffled  = diffusion_shuffled .drop(drop_columns, axis = 1)
labels = GaussianMixture(n_components=2, random_state=0).fit_predict(diffusion_shuffled)

# %%
train_X_diffu, test_X_diffu,train_label_diffu, test_label_diffu = train_test_split(
    diffusion_shuffled, labels, test_size=0.33, random_state=42)

train_X_diffu_tensor = torch.tensor(train_X_diffu.values )
test_X_diffu_tensor = torch.tensor(test_X_diffu.values )

# %%
distance = None
margin = 2

lam = 1
# method = 'sct'
method = 'hn' #shn now is the best
loss_fn = SCTLossCosine( method = method, lam = lam)

lr = 1e-4

hidden_size = 100
embedding_size = 20
input_size = train_X_diffu_tensor.shape[1]
net = EmbeddingNet(input_size, hidden_size, embedding_size)
siamese_net = SiameseNet(  embedding_net = net )



model = siamese_net
model = model.float() 
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 80

datasampler = BatchPairSampling( dataset = train_X_diffu_tensor, labels= train_label_diffu)
batch_size = 100
train_loader = torch.utils.data.DataLoader(datasampler, batch_size=batch_size, shuffle=True)

interval = 10

# %%
# %%time
fit(train_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, interval)
# Out:
# Train: [0/273 (0%)]	Loss: 0.655756
# Epoch: 1/80. Train set: Average loss: 0.6462
# Train: [0/273 (0%)]	Loss: 0.613153
# Epoch: 2/80. Train set: Average loss: 0.6101
# Train: [0/273 (0%)]	Loss: 0.600639
# Epoch: 3/80. Train set: Average loss: 0.5801
# Train: [0/273 (0%)]	Loss: 0.544872
# Epoch: 4/80. Train set: Average loss: 0.5398
# Train: [0/273 (0%)]	Loss: 0.516456
# Epoch: 5/80. Train set: Average loss: 0.4974
# Train: [0/273 (0%)]	Loss: 0.495189
# Epoch: 6/80. Train set: Average loss: 0.4691
# Train: [0/273 (0%)]	Loss: 0.458115
# Epoch: 7/80. Train set: Average loss: 0.4662
# Train: [0/273 (0%)]	Loss: 0.464639
# Epoch: 8/80. Train set: Average loss: 0.4335
# Train: [0/273 (0%)]	Loss: 0.400644
# Epoch: 9/80. Train set: Average loss: 0.4131
# Train: [0/273 (0%)]	Loss: 0.409280
# Epoch: 10/80. Train set: Average loss: 0.4071
# Train: [0/273 (0%)]	Loss: 0.357666
# Epoch: 11/80. Train set: Average loss: 0.3843
# Train: [0/273 (0%)]	Loss: 0.406813
# Epoch: 12/80. Train set: Average loss: 0.3715
# Train: [0/273 (0%)]	Loss: 0.362100
# Epoch: 13/80. Train set: Average loss: 0.3555
# Train: [0/273 (0%)]	Loss: 0.362120
# Epoch: 14/80. Train set: Average loss: 0.3498
# Train: [0/273 (0%)]	Loss: 0.403789
# Epoch: 15/80. Train set: Average loss: 0.3225
# Train: [0/273 (0%)]	Loss: 0.345079
# Epoch: 16/80. Train set: Average loss: 0.3284
# Train: [0/273 (0%)]	Loss: 0.320213
# Epoch: 17/80. Train set: Average loss: 0.3550
# Train: [0/273 (0%)]	Loss: 0.329432
# Epoch: 18/80. Train set: Average loss: 0.3562
# Train: [0/273 (0%)]	Loss: 0.371924
# Epoch: 19/80. Train set: Average loss: 0.3293
# Train: [0/273 (0%)]	Loss: 0.357018
# Epoch: 20/80. Train set: Average loss: 0.2902
# Train: [0/273 (0%)]	Loss: 0.326844
# Epoch: 21/80. Train set: Average loss: 0.3412
# Train: [0/273 (0%)]	Loss: 0.346000
# Epoch: 22/80. Train set: Average loss: 0.3536
# Train: [0/273 (0%)]	Loss: 0.310890
# Epoch: 23/80. Train set: Average loss: 0.3400
# Train: [0/273 (0%)]	Loss: 0.327699
# Epoch: 24/80. Train set: Average loss: 0.3557
# Train: [0/273 (0%)]	Loss: 0.369218
# Epoch: 25/80. Train set: Average loss: 0.3652
# Train: [0/273 (0%)]	Loss: 0.373215
# Epoch: 26/80. Train set: Average loss: 0.3561
# Train: [0/273 (0%)]	Loss: 0.333806
# Epoch: 27/80. Train set: Average loss: 0.3357
# Train: [0/273 (0%)]	Loss: 0.302094
# Epoch: 28/80. Train set: Average loss: 0.3212
# Train: [0/273 (0%)]	Loss: 0.376553
# Epoch: 29/80. Train set: Average loss: 0.3148
# Train: [0/273 (0%)]	Loss: 0.358926
# Epoch: 30/80. Train set: Average loss: 0.3346
# Train: [0/273 (0%)]	Loss: 0.343657
# Epoch: 31/80. Train set: Average loss: 0.3592
# Train: [0/273 (0%)]	Loss: 0.265044
# Epoch: 32/80. Train set: Average loss: 0.2922
# Train: [0/273 (0%)]	Loss: 0.327120
# Epoch: 33/80. Train set: Average loss: 0.3218
# Train: [0/273 (0%)]	Loss: 0.339705
# Epoch: 34/80. Train set: Average loss: 0.3428
# Train: [0/273 (0%)]	Loss: 0.319672
# Epoch: 35/80. Train set: Average loss: 0.3450
# Train: [0/273 (0%)]	Loss: 0.349197
# Epoch: 36/80. Train set: Average loss: 0.3526
# Train: [0/273 (0%)]	Loss: 0.252783
# Epoch: 37/80. Train set: Average loss: 0.3285
# Train: [0/273 (0%)]	Loss: 0.350239
# Epoch: 38/80. Train set: Average loss: 0.3469
# Train: [0/273 (0%)]	Loss: 0.348169
# Epoch: 39/80. Train set: Average loss: 0.3337
# Train: [0/273 (0%)]	Loss: 0.345290
# Epoch: 40/80. Train set: Average loss: 0.3297
# Train: [0/273 (0%)]	Loss: 0.269956
# Epoch: 41/80. Train set: Average loss: 0.3319
# Train: [0/273 (0%)]	Loss: 0.272815
# Epoch: 42/80. Train set: Average loss: 0.3184
# Train: [0/273 (0%)]	Loss: 0.347101
# Epoch: 43/80. Train set: Average loss: 0.3125
# Train: [0/273 (0%)]	Loss: 0.378470
# Epoch: 44/80. Train set: Average loss: 0.3583
# Train: [0/273 (0%)]	Loss: 0.375661
# Epoch: 45/80. Train set: Average loss: 0.3774
# Train: [0/273 (0%)]	Loss: 0.346633
# Epoch: 46/80. Train set: Average loss: 0.3682
# Train: [0/273 (0%)]	Loss: 0.325417
# Epoch: 47/80. Train set: Average loss: 0.3420
# Train: [0/273 (0%)]	Loss: 0.336676
# Epoch: 48/80. Train set: Average loss: 0.3290
# Train: [0/273 (0%)]	Loss: 0.324120
# Epoch: 49/80. Train set: Average loss: 0.3202
# Train: [0/273 (0%)]	Loss: 0.347933
# Epoch: 50/80. Train set: Average loss: 0.3481
# Train: [0/273 (0%)]	Loss: 0.344636
# Epoch: 51/80. Train set: Average loss: 0.3259
# Train: [0/273 (0%)]	Loss: 0.356200
# Epoch: 52/80. Train set: Average loss: 0.3534
# Train: [0/273 (0%)]	Loss: 0.347570
# Epoch: 53/80. Train set: Average loss: 0.3676
# Train: [0/273 (0%)]	Loss: 0.317504
# Epoch: 54/80. Train set: Average loss: 0.3392
# Train: [0/273 (0%)]	Loss: 0.339462
# Epoch: 55/80. Train set: Average loss: 0.3530
# Train: [0/273 (0%)]	Loss: 0.330418
# Epoch: 56/80. Train set: Average loss: 0.3631
# Train: [0/273 (0%)]	Loss: 0.364968
# Epoch: 57/80. Train set: Average loss: 0.3521
# Train: [0/273 (0%)]	Loss: 0.385673
# Epoch: 58/80. Train set: Average loss: 0.3742
# Train: [0/273 (0%)]	Loss: 0.380496
# Epoch: 59/80. Train set: Average loss: 0.3608
# Train: [0/273 (0%)]	Loss: 0.340238
# Epoch: 60/80. Train set: Average loss: 0.3589
# Train: [0/273 (0%)]	Loss: 0.349423
# Epoch: 61/80. Train set: Average loss: 0.3257
# Train: [0/273 (0%)]	Loss: 0.353071
# Epoch: 62/80. Train set: Average loss: 0.3573
# Train: [0/273 (0%)]	Loss: 0.306384
# Epoch: 63/80. Train set: Average loss: 0.3184
# Train: [0/273 (0%)]	Loss: 0.331008
# Epoch: 64/80. Train set: Average loss: 0.3451
# Train: [0/273 (0%)]	Loss: 0.359514
# Epoch: 65/80. Train set: Average loss: 0.3594
# Train: [0/273 (0%)]	Loss: 0.375756
# Epoch: 66/80. Train set: Average loss: 0.3416
# Train: [0/273 (0%)]	Loss: 0.422050
# Epoch: 67/80. Train set: Average loss: 0.3607
# Train: [0/273 (0%)]	Loss: 0.357254
# Epoch: 68/80. Train set: Average loss: 0.3469
# Train: [0/273 (0%)]	Loss: 0.396898
# Epoch: 69/80. Train set: Average loss: 0.3190
# Train: [0/273 (0%)]	Loss: 0.385478
# Epoch: 70/80. Train set: Average loss: 0.3650
# Train: [0/273 (0%)]	Loss: 0.381268
# Epoch: 71/80. Train set: Average loss: 0.3349
# Train: [0/273 (0%)]	Loss: 0.333202
# Epoch: 72/80. Train set: Average loss: 0.3485
# Train: [0/273 (0%)]	Loss: 0.361777
# Epoch: 73/80. Train set: Average loss: 0.3199
# Train: [0/273 (0%)]	Loss: 0.308684
# Epoch: 74/80. Train set: Average loss: 0.3121
# Train: [0/273 (0%)]	Loss: 0.357265
# Epoch: 75/80. Train set: Average loss: 0.3520
# Train: [0/273 (0%)]	Loss: 0.369143
# Epoch: 76/80. Train set: Average loss: 0.3328
# Train: [0/273 (0%)]	Loss: 0.346729
# Epoch: 77/80. Train set: Average loss: 0.3627
# Train: [0/273 (0%)]	Loss: 0.377345
# Epoch: 78/80. Train set: Average loss: 0.3634
# Train: [0/273 (0%)]	Loss: 0.280076
# Epoch: 79/80. Train set: Average loss: 0.3324
# Train: [0/273 (0%)]	Loss: 0.359345
# Epoch: 80/80. Train set: Average loss: 0.3435
# CPU times: user 2.22 s, sys: 276 ms, total: 2.5 s
# Wall time: 2.39 s

# %% [markdown]
# #### Visualize train

# %%
train_embs,train_labels = extract_embeddings(train_X_diffu_tensor , train_label_diffu, model)
name = 'cosine'
train_dis = dissim_matrix(train_embs, name)
embedded_2_train = mds.fit_transform(train_dis)
plot_embeddings(embedded_2_train, train_labels)

# %%
name = 'cosine'
train_orig_dis = dissim_matrix(train_X_diffu_tensor, name)

embedded_2_train_orig = mds.fit_transform(train_orig_dis)
plot_embeddings(embedded_2_train_orig, train_labels)

# %% [markdown]
# #### Visualize test

# %%
test_embs,test_labels = extract_embeddings(test_X_diffu_tensor , test_label_diffu, model)
name = 'cosine'
test_dis = dissim_matrix(test_embs, name)
embedded_2_test = mds.fit_transform(test_dis)
plot_embeddings(embedded_2_test, test_labels)

# %%
name = 'cosine'
test_orig_dis = dissim_matrix(test_X_diffu_tensor, name)

embedded_2_test_orig = mds.fit_transform(test_orig_dis)
plot_embeddings(embedded_2_test_orig, test_labels)

# %% [markdown]
# ### Supercond - GS mixture

# %%
supercond = pd.read_excel('./data/Supercon_data_features_selected.xlsx')
supercond_shuffled = supercond.sample(frac=1).reset_index(drop=True)

drop_columns = [
                 'name',
                 'group',
                 'Tc', 'ln(Tc)'
                 ]
supercond_shuffled  = supercond_shuffled .drop(drop_columns, axis = 1)

labels = GaussianMixture(n_components=2, random_state=0).fit_predict(supercond_shuffled )

# %%
train_X_supercond, test_X_supercond,train_label_supercond, test_label_supercond = train_test_split(
    supercond_shuffled, labels, test_size=0.33, random_state=42)

train_X_supercond_tensor = torch.tensor(train_X_supercond.values )
test_X_supercond_tensor = torch.tensor(test_X_supercond.values )

# %%
distance = None
margin = 2

lam = 1
# method = 'sct'
method = 'hn' #shn now is the best
loss_fn = SCTLossCosine( method = method, lam = lam)
lr = 1e-4

hidden_size = 100
embedding_size = 20
input_size = train_X_supercond_tensor.shape[1]
net = EmbeddingNet(input_size, hidden_size, embedding_size)
siamese_net = SiameseNet(  embedding_net = net )



model = siamese_net
model = model.float() 
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 50

datasampler = BatchPairSampling( dataset = train_X_supercond_tensor, labels= train_label_supercond)
batch_size = 25
train_loader = torch.utils.data.DataLoader(datasampler, batch_size=batch_size, shuffle=True)

interval = 200

# %%
# %%time
fit(train_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, interval)
# Out:
# Train: [0/4188 (0%)]	Loss: 0.672064
# Epoch: 1/50. Train set: Average loss: 0.3577
# Train: [0/4188 (0%)]	Loss: 0.320083
# Epoch: 2/50. Train set: Average loss: 0.3134
# Train: [0/4188 (0%)]	Loss: 0.221162
# Epoch: 3/50. Train set: Average loss: 0.3076
# Train: [0/4188 (0%)]	Loss: 0.190593
# Epoch: 4/50. Train set: Average loss: 0.2792
# Train: [0/4188 (0%)]	Loss: 0.150628
# Epoch: 5/50. Train set: Average loss: 0.3078
# Train: [0/4188 (0%)]	Loss: 0.331594
# Epoch: 6/50. Train set: Average loss: 0.2833
# Train: [0/4188 (0%)]	Loss: 0.499744
# Epoch: 7/50. Train set: Average loss: 0.2905
# Train: [0/4188 (0%)]	Loss: 0.219808
# Epoch: 8/50. Train set: Average loss: 0.2866
# Train: [0/4188 (0%)]	Loss: 0.165455
# Epoch: 9/50. Train set: Average loss: 0.2513
# Train: [0/4188 (0%)]	Loss: 0.210123
# Epoch: 10/50. Train set: Average loss: 0.2429
# Train: [0/4188 (0%)]	Loss: 0.234910
# Epoch: 11/50. Train set: Average loss: 0.2475
# Train: [0/4188 (0%)]	Loss: 0.289102
# Epoch: 12/50. Train set: Average loss: 0.2385
# Train: [0/4188 (0%)]	Loss: 0.134726
# Epoch: 13/50. Train set: Average loss: 0.2328
# Train: [0/4188 (0%)]	Loss: 0.344704
# Epoch: 14/50. Train set: Average loss: 0.2409
# Train: [0/4188 (0%)]	Loss: 0.298995
# Epoch: 15/50. Train set: Average loss: 0.2486
# Train: [0/4188 (0%)]	Loss: 0.270823
# Epoch: 16/50. Train set: Average loss: 0.2412
# Train: [0/4188 (0%)]	Loss: 0.175008
# Epoch: 17/50. Train set: Average loss: 0.2289
# Train: [0/4188 (0%)]	Loss: 0.175609
# Epoch: 18/50. Train set: Average loss: 0.2339
# Train: [0/4188 (0%)]	Loss: 0.198693
# Epoch: 19/50. Train set: Average loss: 0.2262
# Train: [0/4188 (0%)]	Loss: 0.205681
# Epoch: 20/50. Train set: Average loss: 0.2321
# Train: [0/4188 (0%)]	Loss: 0.215822
# Epoch: 21/50. Train set: Average loss: 0.2339
# Train: [0/4188 (0%)]	Loss: 0.183330
# Epoch: 22/50. Train set: Average loss: 0.2346
# Train: [0/4188 (0%)]	Loss: 0.164635
# Epoch: 23/50. Train set: Average loss: 0.2335
# Train: [0/4188 (0%)]	Loss: 0.084901
# Epoch: 24/50. Train set: Average loss: 0.2359
# Train: [0/4188 (0%)]	Loss: 0.430561
# Epoch: 25/50. Train set: Average loss: 0.2368
# Train: [0/4188 (0%)]	Loss: 0.244330
# Epoch: 26/50. Train set: Average loss: 0.2304
# Train: [0/4188 (0%)]	Loss: 0.175447
# Epoch: 27/50. Train set: Average loss: 0.2221
# Train: [0/4188 (0%)]	Loss: 0.178678
# Epoch: 28/50. Train set: Average loss: 0.2295
# Train: [0/4188 (0%)]	Loss: 0.166918
# Epoch: 29/50. Train set: Average loss: 0.2271
# Train: [0/4188 (0%)]	Loss: 0.230711
# Epoch: 30/50. Train set: Average loss: 0.2276
# Train: [0/4188 (0%)]	Loss: 0.130340
# Epoch: 31/50. Train set: Average loss: 0.2312
# Train: [0/4188 (0%)]	Loss: 0.267220
# Epoch: 32/50. Train set: Average loss: 0.2266
# Train: [0/4188 (0%)]	Loss: 0.261374
# Epoch: 33/50. Train set: Average loss: 0.2211
# Train: [0/4188 (0%)]	Loss: 0.243635
# Epoch: 34/50. Train set: Average loss: 0.2233
# Train: [0/4188 (0%)]	Loss: 0.217499
# Epoch: 35/50. Train set: Average loss: 0.2351
# Train: [0/4188 (0%)]	Loss: 0.179551
# Epoch: 36/50. Train set: Average loss: 0.2290
# Train: [0/4188 (0%)]	Loss: 0.326502
# Epoch: 37/50. Train set: Average loss: 0.2326
# Train: [0/4188 (0%)]	Loss: 0.311743
# Epoch: 38/50. Train set: Average loss: 0.2278
# Train: [0/4188 (0%)]	Loss: 0.291324
# Epoch: 39/50. Train set: Average loss: 0.2337
# Train: [0/4188 (0%)]	Loss: 0.190418
# Epoch: 40/50. Train set: Average loss: 0.2412
# Train: [0/4188 (0%)]	Loss: 0.151149
# Epoch: 41/50. Train set: Average loss: 0.2244
# Train: [0/4188 (0%)]	Loss: 0.113655
# Epoch: 42/50. Train set: Average loss: 0.2364
# Train: [0/4188 (0%)]	Loss: 0.205900
# Epoch: 43/50. Train set: Average loss: 0.2274
# Train: [0/4188 (0%)]	Loss: 0.175779
# Epoch: 44/50. Train set: Average loss: 0.2270
# Train: [0/4188 (0%)]	Loss: 0.192043
# Epoch: 45/50. Train set: Average loss: 0.2328
# Train: [0/4188 (0%)]	Loss: 0.168021
# Epoch: 46/50. Train set: Average loss: 0.2325
# Train: [0/4188 (0%)]	Loss: 0.189973
# Epoch: 47/50. Train set: Average loss: 0.2290
# Train: [0/4188 (0%)]	Loss: 0.094106
# Epoch: 48/50. Train set: Average loss: 0.2275
# Train: [0/4188 (0%)]	Loss: 0.350892
# Epoch: 49/50. Train set: Average loss: 0.2330
# Train: [0/4188 (0%)]	Loss: 0.296284
# Epoch: 50/50. Train set: Average loss: 0.2340
# CPU times: user 35.3 s, sys: 870 ms, total: 36.2 s
# Wall time: 35.9 s

# %% [markdown]
# #### Visualize train

# %%
train_embs,train_labels = extract_embeddings(train_X_supercond_tensor , train_label_supercond, model)


# sample some of them for plotting
embs_resample_train, labels_resample_train = smaples_for_plotting(0.5, train_label_supercond, train_embs)

name = 'cosine'
train_dis = dissim_matrix(embs_resample_train, name)
embedded_2_train = mds.fit_transform(train_dis)
plot_embeddings(embedded_2_train, labels_resample_train)

# %%
orig_data_train, labels_resample_orig_train = smaples_for_plotting(0.5, train_label_supercond,train_X_supercond_tensor)

name = 'cosine'
train_orig_dis = dissim_matrix(orig_data_train, name)

embedded_2_train_orig = mds.fit_transform(train_orig_dis)
plot_embeddings(embedded_2_train_orig, labels_resample_orig_train)

# %% [markdown]
# #### Visualize test

# %%
test_embs,test_labels = extract_embeddings(test_X_supercond_tensor , test_label_supercond, model)


# sample some of them for plotting
embs_resample_test, labels_resample_test = smaples_for_plotting(0.5, test_label_supercond, test_embs)

name = 'cosine'
test_dis = dissim_matrix(embs_resample_test, name)
embedded_2_test = mds.fit_transform(test_dis)
plot_embeddings(embedded_2_test, labels_resample_test)

# %%
orig_data_test, labels_resample_orig_test = smaples_for_plotting(0.5, test_label_supercond,test_X_supercond_tensor)

name = 'cosine'
test_orig_dis = dissim_matrix(orig_data_test, name)

embedded_2_test_orig = mds.fit_transform(test_orig_dis)
plot_embeddings(embedded_2_test_orig , labels_resample_orig_test)
