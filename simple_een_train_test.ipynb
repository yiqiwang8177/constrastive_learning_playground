# %%
import pandas as pd
import numpy as np
import sklearn

import matplotlib
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE
# %matplotlib inline

# %%
import torch

from torch.optim import lr_scheduler
import torch.optim as optim
from torch.autograd import Variable

from trainer import fit,train_epoch
import numpy as np
cuda = torch.cuda.is_available()

# %%
from datasets import TripletSampling, BatchPairSampling
from networks import EmbeddingNet, TripletNet, SiameseNet
from losses import TripletLoss,  EasyEasyNegativesBatchLoss, SCTLossCosine

# %%
def extract_embeddings(dataset, labels, model):
    with torch.no_grad():
        model.eval()
        embeddings = []

        for data in dataset:

            embeddings.append( 
                np.array( 
                    model.get_embedding(data).detach().numpy() ) )

    return np.array(embeddings), labels

def plot_embeddings(embeddings, targets, xlim=None, ylim=None):
    plt.figure(figsize=(10,10))
    targets = np.array(targets)
    colors = ['r', 'b']
    shapes = ['*', '^']
    for cls in set(targets):
        mask = targets == cls
        cls_emb = embeddings[mask]
        plt.scatter(cls_emb[:,0], cls_emb[:,1], alpha=0.5, marker = shapes[cls],c = colors[cls])

    plt.legend(set(targets))
    
def dissim_matrix(data, name):
    """helper for mds visualization"""
    from scipy.spatial import distance
    return distance.cdist(data, data, metric= name)

def smaples_for_plotting(percentage, labels, data):
    """ reduce # of data, for plotting"""
    percentage = 0.5
    labels = np.array(labels)
    label_to_indices = {label: np.where(labels == label)[0]
                             for label in labels}


    true_num = int( len(label_to_indices[1]) * percentage )
    false_num = int( len(label_to_indices[0]) * percentage )

    positive_index = np.random.choice( label_to_indices[1], true_num)
    negative_index= np.random.choice(label_to_indices[0], false_num)

    index = np.concatenate( [positive_index, negative_index], axis = 0)

    return data[index], labels[index]


tsne = TSNE(n_components=2, perplexity = 5, learning_rate='auto',init='random')
mds = sklearn.manifold.MDS(n_components=2,metric= True, 
                                  n_init=4, 
                                  max_iter=100,
                                  verbose=0, eps=0.001, n_jobs=-1, random_state= 10, dissimilarity='precomputed')

# %% [markdown]
# ## Friedman

# %%
friedman = pd.read_csv('./data/Friedman_data.csv')
drop_columns = ['y']
friedman = friedman.drop(drop_columns, axis = 1)

# %%
friedman_shuffled = friedman.sample(frac=1).reset_index(drop=True)
from sklearn.mixture import GaussianMixture

# use Gs to do clustering
labels = GaussianMixture(n_components=2, random_state=0).fit_predict(friedman_shuffled)

# %%
train_X_fried, test_X_fried,train_label_fried, test_label_fried = train_test_split(
    friedman_shuffled, labels, test_size=0.33, random_state=42)

train_X_fried_tensor = torch.tensor(train_X_fried.values )
test_X_fried_tensor = torch.tensor(test_X_fried.values )

# %%
distance = None
margin = 1
loss_fn = EasyEasyNegativesBatchLoss( margin = margin, distance = distance)
lr = 1e-3

hidden_size = 20
embedding_size = 5
input_size = train_X_fried_tensor.shape[1]

net = EmbeddingNet(input_size, hidden_size, embedding_size)
siamese_net = SiameseNet(  embedding_net = net )



model = siamese_net
model = model.float() 
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 20

datasampler = BatchPairSampling( dataset = train_X_fried_tensor , labels= train_label_fried)
batch_size = 8 
train_loader = torch.utils.data.DataLoader(datasampler, batch_size=batch_size, shuffle=True)

interval = 20

# %%
# %%time
fit(train_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, interval)
# Out:
# Train: [0/670 (0%)]	Loss: 0.992466
# Train: [160/670 (24%)]	Loss: 0.943726
# Train: [320/670 (48%)]	Loss: 0.366651
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 1/20. Train set: Average loss: 0.3238
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 2/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 3/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 4/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 5/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 6/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 7/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 8/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 9/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 10/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 11/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 12/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 13/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 14/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 15/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 16/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 17/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 18/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 19/20. Train set: Average loss: 0.0000
# Train: [0/670 (0%)]	Loss: 0.000000
# Train: [160/670 (24%)]	Loss: 0.000000
# Train: [320/670 (48%)]	Loss: 0.000000
# Train: [480/670 (71%)]	Loss: 0.000000
# Train: [640/670 (95%)]	Loss: 0.000000
# Epoch: 20/20. Train set: Average loss: 0.0000
# CPU times: user 4.45 s, sys: 48.4 ms, total: 4.5 s
# Wall time: 4.5 s

# %% [markdown]
# #### Visualize train

# %%
train_embs,train_labels = extract_embeddings(train_X_fried_tensor , train_label_fried, model)

# %%
name = 'euclidean'
train_dis = dissim_matrix(train_embs, name)

# %%
embedded_2_train = mds.fit_transform(train_dis)
plot_embeddings(embedded_2_train, train_labels)

# %%
name = 'euclidean'
train_orig_dis = dissim_matrix(train_X_fried_tensor, name)

embedded_2_train_orig = mds.fit_transform(train_orig_dis)
plot_embeddings(embedded_2_train_orig, train_labels)

# %% [markdown]
# #### visualize test

# %%
test_embs,test_labels = extract_embeddings(test_X_fried_tensor , test_label_fried, model)

# %%
name = 'euclidean'
test_dis = dissim_matrix(test_embs, name)

# %%
embedded_2_test = mds.fit_transform(test_dis)
plot_embeddings(embedded_2_test, test_labels)

# %%
name = 'euclidean'
test_orig_dis = dissim_matrix(test_X_fried_tensor, name)

embedded_2_test_orig = mds.fit_transform(test_orig_dis)
plot_embeddings(embedded_2_test_orig, test_labels)

# %% [markdown]
# ## Diffusion - chemical grouping

# %%
diffusion = pd.read_csv('./data/Diffusion_data.csv')
diffusion_shuffled = diffusion.sample(frac=1).reset_index(drop=True)
labels = []
for name in diffusion_shuffled ['group']:
    if name == 'transition_metal':
        labels.append(1)
    else:
        labels.append(0)

drop_columns = ['E_regression', 'E_regression_shift', 'group',
               'Material compositions 2', 'Material compositions 1']
diffusion_shuffled  = diffusion_shuffled .drop(drop_columns, axis = 1)

# %%
sum(labels)/len(labels)
# Out:
# 0.33088235294117646

# %%
train_X_diffu, test_X_diffu,train_label_diffu, test_label_diffu = train_test_split(
    diffusion_shuffled, labels, test_size=0.33, random_state=42)

train_X_diffu_tensor = torch.tensor(train_X_diffu.values )
test_X_diffu_tensor = torch.tensor(test_X_diffu.values )

# %%
distance = None
margin = 1
loss_fn = EasyEasyNegativesBatchLoss( margin = margin, distance = distance)
# loss_fn = loss_fn2
lr = 1e-3

hidden_size = 100
embedding_size = 20
input_size = train_X_diffu_tensor.shape[1]
net = EmbeddingNet(input_size, hidden_size, embedding_size)
siamese_net = SiameseNet(  embedding_net = net )



model = siamese_net
model = model.float() 
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 20

datasampler = BatchPairSampling( dataset = train_X_diffu_tensor, labels= train_label_diffu)
batch_size = 8 
train_loader = torch.utils.data.DataLoader(datasampler, batch_size=batch_size, shuffle=True)

interval = 10

# %%
# %%time
fit(train_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, interval)
# Out:
# Train: [0/273 (0%)]	Loss: 0.789111
# Train: [80/273 (29%)]	Loss: 0.124026
# Train: [160/273 (57%)]	Loss: 0.033717
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 1/20. Train set: Average loss: 0.0915
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.007085
# Epoch: 2/20. Train set: Average loss: 0.0020
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.003230
# Train: [160/273 (57%)]	Loss: 0.013540
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 3/20. Train set: Average loss: 0.0108
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.010463
# Epoch: 4/20. Train set: Average loss: 0.0499
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.034746
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 5/20. Train set: Average loss: 0.0240
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.019973
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 6/20. Train set: Average loss: 0.0057
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 7/20. Train set: Average loss: 0.0275
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 8/20. Train set: Average loss: 0.0087
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 9/20. Train set: Average loss: 0.0266
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 10/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 11/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 12/20. Train set: Average loss: 0.0280
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 13/20. Train set: Average loss: 0.0220
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 14/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 15/20. Train set: Average loss: 0.0018
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 16/20. Train set: Average loss: 0.0278
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 17/20. Train set: Average loss: 0.0084
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.055997
# Epoch: 18/20. Train set: Average loss: 0.0442
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 19/20. Train set: Average loss: 0.0000
# Train: [0/273 (0%)]	Loss: 0.000000
# Train: [80/273 (29%)]	Loss: 0.000000
# Train: [160/273 (57%)]	Loss: 0.000000
# Train: [240/273 (86%)]	Loss: 0.000000
# Epoch: 20/20. Train set: Average loss: 0.0197
# CPU times: user 2.27 s, sys: 134 ms, total: 2.4 s
# Wall time: 2.33 s

# %% [markdown]
# #### Visualize train

# %%
train_embs,train_labels = extract_embeddings(train_X_diffu_tensor , train_label_diffu, model)
name = 'euclidean'
train_dis = dissim_matrix(train_embs, name)
embedded_2_train = mds.fit_transform(train_dis)
plot_embeddings(embedded_2_train, train_labels)

# %%
name = 'euclidean'
train_orig_dis = dissim_matrix(train_X_diffu_tensor, name)

embedded_2_train_orig = mds.fit_transform(train_orig_dis)
plot_embeddings(embedded_2_train_orig, train_labels)

# %% [markdown]
# #### Visualize test

# %%
test_embs,test_labels = extract_embeddings(test_X_diffu_tensor , test_label_diffu, model)
name = 'euclidean'
test_dis = dissim_matrix(test_embs, name)
embedded_2_test = mds.fit_transform(test_dis)
plot_embeddings(embedded_2_test, test_labels)

# %%
name = 'euclidean'
test_orig_dis = dissim_matrix(test_X_diffu_tensor, name)

embedded_2_test_orig = mds.fit_transform(test_orig_dis)
plot_embeddings(embedded_2_test_orig, test_labels)

# %% [markdown]
# ### Supercond - chemical grouping

# %%
supercond = pd.read_excel('./data/Supercon_data_features_selected.xlsx')
supercond_shuffled = supercond.sample(frac=1).reset_index(drop=True)

labels = []
for name in supercond['group']:
    if name == 'cuprates':
        labels.append(1)
    else:
        labels.append(0)
supercond['group'] = labels


drop_columns = [
                 'name',
                 'group',
                 'Tc', 'ln(Tc)'
                 ]
supercond_shuffled  = supercond_shuffled .drop(drop_columns, axis = 1)

# %%
train_X_supercond, test_X_supercond,train_label_supercond, test_label_supercond = train_test_split(
    supercond_shuffled, labels, test_size=0.33, random_state=42)

train_X_supercond_tensor = torch.tensor(train_X_supercond.values )
test_X_supercond_tensor = torch.tensor(test_X_supercond.values )

# %%
distance = None
margin = 2
loss_fn = EasyEasyNegativesBatchLoss( margin = margin, distance = distance)
# loss_fn = loss_fn2
lr = 1e-4

hidden_size = 100
embedding_size = 20
input_size = train_X_supercond_tensor.shape[1]
net = EmbeddingNet(input_size, hidden_size, embedding_size)
siamese_net = SiameseNet(  embedding_net = net )



model = siamese_net
model = model.float() 
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 50

datasampler = BatchPairSampling( dataset = train_X_supercond_tensor, labels= train_label_supercond)
batch_size = 25
train_loader = torch.utils.data.DataLoader(datasampler, batch_size=batch_size, shuffle=True)

interval = 200

# %%
# %%time
fit(train_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, interval)
# Out:
# Train: [0/4188 (0%)]	Loss: 1.703079
# Epoch: 1/50. Train set: Average loss: 0.1265
# Train: [0/4188 (0%)]	Loss: 0.005881
# Epoch: 2/50. Train set: Average loss: 0.0037
# Train: [0/4188 (0%)]	Loss: 0.003762
# Epoch: 3/50. Train set: Average loss: 0.0026
# Train: [0/4188 (0%)]	Loss: 0.003645
# Epoch: 4/50. Train set: Average loss: 0.0020
# Train: [0/4188 (0%)]	Loss: 0.000353
# Epoch: 5/50. Train set: Average loss: 0.0026
# Train: [0/4188 (0%)]	Loss: 0.002146
# Epoch: 6/50. Train set: Average loss: 0.0015
# Train: [0/4188 (0%)]	Loss: 0.001379
# Epoch: 7/50. Train set: Average loss: 0.0008
# Train: [0/4188 (0%)]	Loss: 0.001658
# Epoch: 8/50. Train set: Average loss: 0.0006
# Train: [0/4188 (0%)]	Loss: 0.000344
# Epoch: 9/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000223
# Epoch: 10/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000606
# Epoch: 11/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000509
# Epoch: 12/50. Train set: Average loss: 0.0005
# Train: [0/4188 (0%)]	Loss: 0.000272
# Epoch: 13/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000692
# Epoch: 14/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000548
# Epoch: 15/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000339
# Epoch: 16/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000369
# Epoch: 17/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000103
# Epoch: 18/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000150
# Epoch: 19/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000225
# Epoch: 20/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000263
# Epoch: 21/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000294
# Epoch: 22/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000607
# Epoch: 23/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000395
# Epoch: 24/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000400
# Epoch: 25/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000791
# Epoch: 26/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000500
# Epoch: 27/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000664
# Epoch: 28/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000093
# Epoch: 29/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000398
# Epoch: 30/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000069
# Epoch: 31/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000220
# Epoch: 32/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.001323
# Epoch: 33/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000347
# Epoch: 34/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000295
# Epoch: 35/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000399
# Epoch: 36/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000312
# Epoch: 37/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000098
# Epoch: 38/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000729
# Epoch: 39/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000045
# Epoch: 40/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000031
# Epoch: 41/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000092
# Epoch: 42/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000247
# Epoch: 43/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000389
# Epoch: 44/50. Train set: Average loss: 0.0004
# Train: [0/4188 (0%)]	Loss: 0.000140
# Epoch: 45/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000386
# Epoch: 46/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000203
# Epoch: 47/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000260
# Epoch: 48/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000453
# Epoch: 49/50. Train set: Average loss: 0.0003
# Train: [0/4188 (0%)]	Loss: 0.000104
# Epoch: 50/50. Train set: Average loss: 0.0003
# CPU times: user 47.8 s, sys: 1.13 s, total: 49 s
# Wall time: 48.7 s

# %% [markdown]
# #### Visualize train

# %%
train_embs,train_labels = extract_embeddings(train_X_supercond_tensor , train_label_supercond, model)


# sample some of them for plotting
embs_resample_train, labels_resample_train = smaples_for_plotting(0.5, train_label_supercond, train_embs)

name = 'euclidean'
train_dis = dissim_matrix(embs_resample_train, name)
embedded_2_train = mds.fit_transform(train_dis)
plot_embeddings(embedded_2_train, labels_resample_train)

# %%
orig_data_train, labels_resample_orig_train = smaples_for_plotting(0.5, train_label_supercond,train_X_supercond_tensor)

name = 'euclidean'
train_orig_dis = dissim_matrix(orig_data_train, name)

embedded_2_train_orig = mds.fit_transform(train_orig_dis)
plot_embeddings(embedded_2_train_orig, labels_resample_orig_train)

# %% [markdown]
# #### visual test

# %%
test_embs,test_labels = extract_embeddings(test_X_supercond_tensor , test_label_supercond, model)


# sample some of them for plotting
embs_resample_test, labels_resample_test = smaples_for_plotting(0.5, test_label_supercond, test_embs)

name = 'euclidean'
test_dis = dissim_matrix(embs_resample_test, name)
embedded_2_test = mds.fit_transform(test_dis)
plot_embeddings(embedded_2_test, labels_resample_test)

# %%
orig_data_test, labels_resample_orig_test = smaples_for_plotting(0.5, test_label_supercond,test_X_supercond_tensor)

name = 'euclidean'
test_orig_dis = dissim_matrix(orig_data_test, name)

embedded_2_test_orig = mds.fit_transform(test_orig_dis)
plot_embeddings(embedded_2_test_orig , labels_resample_orig_test)

# %% [markdown]
# ### Diffusion - gs mixture

# %%
diffusion = pd.read_csv('./data/Diffusion_data.csv')
diffusion_shuffled = diffusion.sample(frac=1).reset_index(drop=True)
drop_columns = ['E_regression', 'E_regression_shift', 'group',
               'Material compositions 2', 'Material compositions 1']
diffusion_shuffled  = diffusion_shuffled .drop(drop_columns, axis = 1)
labels = GaussianMixture(n_components=2, random_state=0).fit_predict(diffusion_shuffled)

# %%
train_X_diffu, test_X_diffu,train_label_diffu, test_label_diffu = train_test_split(
    diffusion_shuffled, labels, test_size=0.33, random_state=42)

train_X_diffu_tensor = torch.tensor(train_X_diffu.values )
test_X_diffu_tensor = torch.tensor(test_X_diffu.values )

# %%
distance = None
margin = 2
loss_fn = EasyEasyNegativesBatchLoss( margin = margin, distance = distance)
# loss_fn = loss_fn2
lr = 1e-3

hidden_size = 100
embedding_size = 20
input_size = train_X_diffu_tensor.shape[1]
net = EmbeddingNet(input_size, hidden_size, embedding_size)
siamese_net = SiameseNet(  embedding_net = net )



model = siamese_net
model = model.float() 
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 20

datasampler = BatchPairSampling( dataset = train_X_diffu_tensor, labels= train_label_diffu)
batch_size = 8 
train_loader = torch.utils.data.DataLoader(datasampler, batch_size=batch_size, shuffle=True)

interval = 10

# %%
# %%time
fit(train_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, interval)
# Out:
# Train: [0/273 (0%)]	Loss: 1.786589
# Train: [80/273 (29%)]	Loss: 0.245985
# Train: [160/273 (57%)]	Loss: 0.031875
# Train: [240/273 (86%)]	Loss: 0.853611
# Epoch: 1/20. Train set: Average loss: 0.3830
# Train: [0/273 (0%)]	Loss: 0.072881
# Train: [80/273 (29%)]	Loss: 0.052332
# Train: [160/273 (57%)]	Loss: 0.029562
# Train: [240/273 (86%)]	Loss: 0.026631
# Epoch: 2/20. Train set: Average loss: 0.0341
# Train: [0/273 (0%)]	Loss: 0.006209
# Train: [80/273 (29%)]	Loss: 0.010313
# Train: [160/273 (57%)]	Loss: 0.007850
# Train: [240/273 (86%)]	Loss: 0.004757
# Epoch: 3/20. Train set: Average loss: 0.0081
# Train: [0/273 (0%)]	Loss: 0.001198
# Train: [80/273 (29%)]	Loss: 0.006030
# Train: [160/273 (57%)]	Loss: 0.002466
# Train: [240/273 (86%)]	Loss: 0.003075
# Epoch: 4/20. Train set: Average loss: 0.0035
# Train: [0/273 (0%)]	Loss: 0.003739
# Train: [80/273 (29%)]	Loss: 0.003112
# Train: [160/273 (57%)]	Loss: 0.002793
# Train: [240/273 (86%)]	Loss: 0.004333
# Epoch: 5/20. Train set: Average loss: 0.0032
# Train: [0/273 (0%)]	Loss: 0.001554
# Train: [80/273 (29%)]	Loss: 0.003021
# Train: [160/273 (57%)]	Loss: 0.002224
# Train: [240/273 (86%)]	Loss: 0.002525
# Epoch: 6/20. Train set: Average loss: 0.0027
# Train: [0/273 (0%)]	Loss: 0.001072
# Train: [80/273 (29%)]	Loss: 0.003278
# Train: [160/273 (57%)]	Loss: 0.002582
# Train: [240/273 (86%)]	Loss: 0.002522
# Epoch: 7/20. Train set: Average loss: 0.0570
# Train: [0/273 (0%)]	Loss: 0.002346
# Train: [80/273 (29%)]	Loss: 0.003073
# Train: [160/273 (57%)]	Loss: 0.002263
# Train: [240/273 (86%)]	Loss: 0.001891
# Epoch: 8/20. Train set: Average loss: 0.0047
# Train: [0/273 (0%)]	Loss: 0.003961
# Train: [80/273 (29%)]	Loss: 0.006306
# Train: [160/273 (57%)]	Loss: 0.009845
# Train: [240/273 (86%)]	Loss: 0.006917
# Epoch: 9/20. Train set: Average loss: 0.0071
# Train: [0/273 (0%)]	Loss: 0.000318
# Train: [80/273 (29%)]	Loss: 0.004939
# Train: [160/273 (57%)]	Loss: 0.002604
# Train: [240/273 (86%)]	Loss: 0.004755
# Epoch: 10/20. Train set: Average loss: 0.0041
# Train: [0/273 (0%)]	Loss: 0.001393
# Train: [80/273 (29%)]	Loss: 0.004196
# Train: [160/273 (57%)]	Loss: 0.002446
# Train: [240/273 (86%)]	Loss: 0.003546
# Epoch: 11/20. Train set: Average loss: 0.0033
# Train: [0/273 (0%)]	Loss: 0.002012
# Train: [80/273 (29%)]	Loss: 0.002945
# Train: [160/273 (57%)]	Loss: 0.001935
# Train: [240/273 (86%)]	Loss: 0.002498
# Epoch: 12/20. Train set: Average loss: 0.0030
# Train: [0/273 (0%)]	Loss: 0.001876
# Train: [80/273 (29%)]	Loss: 0.004694
# Train: [160/273 (57%)]	Loss: 0.002264
# Train: [240/273 (86%)]	Loss: 0.002142
# Epoch: 13/20. Train set: Average loss: 0.0591
# Train: [0/273 (0%)]	Loss: 0.000490
# Train: [80/273 (29%)]	Loss: 0.001485
# Train: [160/273 (57%)]	Loss: 0.001389
# Train: [240/273 (86%)]	Loss: 0.002043
# Epoch: 14/20. Train set: Average loss: 0.0557
# Train: [0/273 (0%)]	Loss: 0.000017
# Train: [80/273 (29%)]	Loss: 0.002943
# Train: [160/273 (57%)]	Loss: 0.001580
# Train: [240/273 (86%)]	Loss: 0.001639
# Epoch: 15/20. Train set: Average loss: 0.0018
# Train: [0/273 (0%)]	Loss: 0.000731
# Train: [80/273 (29%)]	Loss: 0.002246
# Train: [160/273 (57%)]	Loss: 0.001793
# Train: [240/273 (86%)]	Loss: 0.001846
# Epoch: 16/20. Train set: Average loss: 0.0022
# Train: [0/273 (0%)]	Loss: 0.001381
# Train: [80/273 (29%)]	Loss: 0.001750
# Train: [160/273 (57%)]	Loss: 0.002014
# Train: [240/273 (86%)]	Loss: 0.002444
# Epoch: 17/20. Train set: Average loss: 0.0019
# Train: [0/273 (0%)]	Loss: 0.002442
# Train: [80/273 (29%)]	Loss: 0.001342
# Train: [160/273 (57%)]	Loss: 0.001334
# Train: [240/273 (86%)]	Loss: 0.001715
# Epoch: 18/20. Train set: Average loss: 0.0016
# Train: [0/273 (0%)]	Loss: 0.001081
# Train: [80/273 (29%)]	Loss: 0.001454
# Train: [160/273 (57%)]	Loss: 0.001434
# Train: [240/273 (86%)]	Loss: 0.002335
# Epoch: 19/20. Train set: Average loss: 0.0016
# Train: [0/273 (0%)]	Loss: 0.001444
# Train: [80/273 (29%)]	Loss: 0.001789
# Train: [160/273 (57%)]	Loss: 0.001339
# Train: [240/273 (86%)]	Loss: 0.000853
# Epoch: 20/20. Train set: Average loss: 0.0013
# CPU times: user 3.1 s, sys: 285 ms, total: 3.38 s
# Wall time: 2.28 s

# %%
#### Visualize train

# %%
train_embs,train_labels = extract_embeddings(train_X_diffu_tensor , train_label_diffu, model)
name = 'euclidean'
train_dis = dissim_matrix(train_embs, name)
embedded_2_train = mds.fit_transform(train_dis)
plot_embeddings(embedded_2_train, train_labels)

# %%
name = 'euclidean'
train_orig_dis = dissim_matrix(train_X_diffu_tensor, name)

embedded_2_train_orig = mds.fit_transform(train_orig_dis)
plot_embeddings(embedded_2_train_orig, train_labels)

# %% [markdown]
# #### Visualize test

# %%
test_embs,test_labels = extract_embeddings(test_X_diffu_tensor , test_label_diffu, model)
name = 'euclidean'
test_dis = dissim_matrix(test_embs, name)
embedded_2_test = mds.fit_transform(test_dis)
plot_embeddings(embedded_2_test, test_labels)

# %%
name = 'euclidean'
test_orig_dis = dissim_matrix(test_X_diffu_tensor, name)

embedded_2_test_orig = mds.fit_transform(test_orig_dis)
plot_embeddings(embedded_2_test_orig, test_labels)

# %% [markdown]
# ### Supercond - GS mixture

# %%
supercond = pd.read_excel('./data/Supercon_data_features_selected.xlsx')
supercond_shuffled = supercond.sample(frac=1).reset_index(drop=True)

drop_columns = [
                 'name',
                 'group',
                 'Tc', 'ln(Tc)'
                 ]
supercond_shuffled  = supercond_shuffled .drop(drop_columns, axis = 1)

labels = GaussianMixture(n_components=2, random_state=0).fit_predict(supercond_shuffled )

# %%
train_X_supercond, test_X_supercond,train_label_supercond, test_label_supercond = train_test_split(
    supercond_shuffled, labels, test_size=0.33, random_state=42)

train_X_supercond_tensor = torch.tensor(train_X_supercond.values )
test_X_supercond_tensor = torch.tensor(test_X_supercond.values )

# %%
distance = None
margin = 2
loss_fn = EasyEasyNegativesBatchLoss( margin = margin, distance = distance)
# loss_fn = loss_fn2
lr = 1e-4

hidden_size = 100
embedding_size = 20
input_size = train_X_supercond_tensor.shape[1]
net = EmbeddingNet(input_size, hidden_size, embedding_size)
siamese_net = SiameseNet(  embedding_net = net )



model = siamese_net
model = model.float() 
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, 8, gamma=0.1, last_epoch=-1)
n_epochs = 50

datasampler = BatchPairSampling( dataset = train_X_supercond_tensor, labels= train_label_supercond)
batch_size = 25
train_loader = torch.utils.data.DataLoader(datasampler, batch_size=batch_size, shuffle=True)

interval = 200

# %%
# %%time
fit(train_loader, model, loss_fn, optimizer, scheduler, n_epochs, cuda, interval)
# Out:
# Train: [0/4188 (0%)]	Loss: 1.365162
# Epoch: 1/50. Train set: Average loss: 0.1203
# Train: [0/4188 (0%)]	Loss: 0.022023
# Epoch: 2/50. Train set: Average loss: 0.0074
# Train: [0/4188 (0%)]	Loss: 0.003976
# Epoch: 3/50. Train set: Average loss: 0.0048
# Train: [0/4188 (0%)]	Loss: 0.004661
# Epoch: 4/50. Train set: Average loss: 0.0029
# Train: [0/4188 (0%)]	Loss: 0.001173
# Epoch: 5/50. Train set: Average loss: 0.0027
# Train: [0/4188 (0%)]	Loss: 0.003516
# Epoch: 6/50. Train set: Average loss: 0.0021
# Train: [0/4188 (0%)]	Loss: 0.001539
# Epoch: 7/50. Train set: Average loss: 0.0015
# Train: [0/4188 (0%)]	Loss: 0.000704
# Epoch: 8/50. Train set: Average loss: 0.0013
# Train: [0/4188 (0%)]	Loss: 0.001230
# Epoch: 9/50. Train set: Average loss: 0.0013
# Train: [0/4188 (0%)]	Loss: 0.000474
# Epoch: 10/50. Train set: Average loss: 0.0011
# Train: [0/4188 (0%)]	Loss: 0.000932
# Epoch: 11/50. Train set: Average loss: 0.0011
# Train: [0/4188 (0%)]	Loss: 0.001230
# Epoch: 12/50. Train set: Average loss: 0.0012
# Train: [0/4188 (0%)]	Loss: 0.000913
# Epoch: 13/50. Train set: Average loss: 0.0012
# Train: [0/4188 (0%)]	Loss: 0.000938
# Epoch: 14/50. Train set: Average loss: 0.0010
# Train: [0/4188 (0%)]	Loss: 0.000340
# Epoch: 15/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000848
# Epoch: 16/50. Train set: Average loss: 0.0010
# Train: [0/4188 (0%)]	Loss: 0.001532
# Epoch: 17/50. Train set: Average loss: 0.0010
# Train: [0/4188 (0%)]	Loss: 0.000625
# Epoch: 18/50. Train set: Average loss: 0.0054
# Train: [0/4188 (0%)]	Loss: 0.000290
# Epoch: 19/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.001752
# Epoch: 20/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000938
# Epoch: 21/50. Train set: Average loss: 0.0010
# Train: [0/4188 (0%)]	Loss: 0.000898
# Epoch: 22/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000355
# Epoch: 23/50. Train set: Average loss: 0.0010
# Train: [0/4188 (0%)]	Loss: 0.000809
# Epoch: 24/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000399
# Epoch: 25/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.001808
# Epoch: 26/50. Train set: Average loss: 0.0008
# Train: [0/4188 (0%)]	Loss: 0.000690
# Epoch: 27/50. Train set: Average loss: 0.0010
# Train: [0/4188 (0%)]	Loss: 0.000670
# Epoch: 28/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000547
# Epoch: 29/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.001100
# Epoch: 30/50. Train set: Average loss: 0.0008
# Train: [0/4188 (0%)]	Loss: 0.001448
# Epoch: 31/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000004
# Epoch: 32/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.001089
# Epoch: 33/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.001279
# Epoch: 34/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000412
# Epoch: 35/50. Train set: Average loss: 0.0010
# Train: [0/4188 (0%)]	Loss: 0.000921
# Epoch: 36/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000947
# Epoch: 37/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.001023
# Epoch: 38/50. Train set: Average loss: 0.0008
# Train: [0/4188 (0%)]	Loss: 0.000080
# Epoch: 39/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000582
# Epoch: 40/50. Train set: Average loss: 0.0008
# Train: [0/4188 (0%)]	Loss: 0.000712
# Epoch: 41/50. Train set: Average loss: 0.0010
# Train: [0/4188 (0%)]	Loss: 0.000509
# Epoch: 42/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000521
# Epoch: 43/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000361
# Epoch: 44/50. Train set: Average loss: 0.0008
# Train: [0/4188 (0%)]	Loss: 0.000563
# Epoch: 45/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000580
# Epoch: 46/50. Train set: Average loss: 0.0008
# Train: [0/4188 (0%)]	Loss: 0.000571
# Epoch: 47/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.001528
# Epoch: 48/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000208
# Epoch: 49/50. Train set: Average loss: 0.0009
# Train: [0/4188 (0%)]	Loss: 0.000814
# Epoch: 50/50. Train set: Average loss: 0.0009
# CPU times: user 49.1 s, sys: 1.39 s, total: 50.5 s
# Wall time: 49.7 s

# %% [markdown]
# #### Visualize train

# %%
train_embs,train_labels = extract_embeddings(train_X_supercond_tensor , train_label_supercond, model)


# sample some of them for plotting
embs_resample_train, labels_resample_train = smaples_for_plotting(0.5, train_label_supercond, train_embs)

name = 'euclidean'
train_dis = dissim_matrix(embs_resample_train, name)
embedded_2_train = mds.fit_transform(train_dis)
plot_embeddings(embedded_2_train, labels_resample_train)

# %%
orig_data_train, labels_resample_orig_train = smaples_for_plotting(0.5, train_label_supercond,train_X_supercond_tensor)

name = 'euclidean'
train_orig_dis = dissim_matrix(orig_data_train, name)

embedded_2_train_orig = mds.fit_transform(train_orig_dis)
plot_embeddings(embedded_2_train_orig, labels_resample_orig_train)

# %% [markdown]
# #### Visualize test

# %%
test_embs,test_labels = extract_embeddings(test_X_supercond_tensor , test_label_supercond, model)


# sample some of them for plotting
embs_resample_test, labels_resample_test = smaples_for_plotting(0.5, test_label_supercond, test_embs)

name = 'euclidean'
test_dis = dissim_matrix(embs_resample_test, name)
embedded_2_test = mds.fit_transform(test_dis)
plot_embeddings(embedded_2_test, labels_resample_test)

# %%
orig_data_test, labels_resample_orig_test = smaples_for_plotting(0.5, test_label_supercond,test_X_supercond_tensor)

name = 'euclidean'
test_orig_dis = dissim_matrix(orig_data_test, name)

embedded_2_test_orig = mds.fit_transform(test_orig_dis)
plot_embeddings(embedded_2_test_orig , labels_resample_orig_test)
